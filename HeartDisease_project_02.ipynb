# %% [markdown]
# <a href="https://colab.research.google.com/github/vidhi-sys/Python-Learning/blob/main/HeartDisease_project_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/heart.csv')

# %%
df.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# ...

# %%
df.tail(10)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 908   63   M           ASY        140          187          0        LVH
# 909   63   F           ASY        124          197          0     Normal
# 910   41   M           ATA        120          157          0     Normal
# 911   59   M           ASY        164          176          1        LVH
# 912   57   F           ASY        140          241          0     Normal
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 908    144              Y      4.0       Up             1
# ...

# %%
print(df.shape[0])
print(df.shape[1])
# Out:
# 918
# 12

# %%
df.drop('Sex', axis=1)
# Out:
#      Age ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0     40           ATA        140          289          0     Normal    172
# 1     49           NAP        160          180          0     Normal    156
# 2     37           ATA        130          283          0         ST     98
# 3     48           ASY        138          214          0     Normal    108
# 4     54           NAP        150          195          0     Normal    122
# ..   ...           ...        ...          ...        ...        ...    ...
# 913   45            TA        110          264          0     Normal    132
# 914   68           ASY        144          193          1     Normal    141
# 915   57           ASY        130          131          0     Normal    115
# 916   57           ATA        130          236          0        LVH    174
# 917   38           NAP        138          175          0     Normal    173
#
#     ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
columns_to_drop = ['ChestPainType', 'RestingBP', 'RestingECG', 'ExerciseAngina', 'ST_Slope']
df = df.drop(columns=columns_to_drop)
display(df.head())
# Out:
#    Age Sex  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0   40   M          289          0    172      0.0             0
# 1   49   F          180          0    156      1.0             1
# 2   37   M          283          0     98      0.0             0
# 3   48   F          214          0    108      1.5             1
# 4   54   M          195          0    122      0.0             0

# %%
print(df.isnull().sum())
# Out:
# Age             0
# Sex             0
# Cholesterol     0
# FastingBS       0
# MaxHR           0
# Oldpeak         0
# HeartDisease    0
# dtype: int64

# %%
print(df.describe())
# Out:
#               Age  Cholesterol   FastingBS       MaxHR     Oldpeak  \
# count  918.000000   918.000000  918.000000  918.000000  918.000000
# mean    53.510893   198.799564    0.233115  136.809368    0.887364
# std      9.432617   109.384145    0.423046   25.460334    1.066570
# min     28.000000     0.000000    0.000000   60.000000   -2.600000
# 25%     47.000000   173.250000    0.000000  120.000000    0.000000
# 50%     54.000000   223.000000    0.000000  138.000000    0.600000
# 75%     60.000000   267.000000    0.000000  156.000000    1.500000
# max     77.000000   603.000000    1.000000  202.000000    6.200000
#
#        HeartDisease
# count    918.000000
# mean       0.553377
# std        0.497414
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
print(df[df['HeartDisease']==True])
# Out:
#      Age Sex  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 1     49   F          180          0    156      1.0             1
# 3     48   F          214          0    108      1.5             1
# 8     37   M          207          0    130      1.5             1
# 11    58   M          164          0     99      2.0             1
# 13    49   M          234          0    140      1.0             1
# ..   ...  ..          ...        ...    ...      ...           ...
# 912   57   F          241          0    123      0.2             1
# 913   45   M          264          0    132      1.2             1
# 914   68   M          193          1    141      3.4             1
# 915   57   M          131          0    115      1.2             1
# 916   57   F          236          0    174      0.0             1
#
# [508 rows x 7 columns]

# %%
print(df.drop_duplicates())
# Out:
#      Age Sex  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0     40   M          289          0    172      0.0             0
# 1     49   F          180          0    156      1.0             1
# 2     37   M          283          0     98      0.0             0
# 3     48   F          214          0    108      1.5             1
# 4     54   M          195          0    122      0.0             0
# ..   ...  ..          ...        ...    ...      ...           ...
# 913   45   M          264          0    132      1.2             1
# 914   68   M          193          1    141      3.4             1
# 915   57   M          131          0    115      1.2             1
# 916   57   F          236          0    174      0.0             1
# 917   38   M          175          0    173      0.0             0
#
# [915 rows x 7 columns]

# %%
print(df[df['Sex']=='F'].sum())
# Out:
# Age                                                         10131
# Sex             FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF...
# Cholesterol                                                 46551
# FastingBS                                                      26
# MaxHR                                                       28205
# Oldpeak                                                     129.1
# HeartDisease                                                   50
# dtype: object

# %%
print(df['Cholesterol'].min())
print(df['Cholesterol'].max())
print(df['Cholesterol'].mean())
print(df['Cholesterol'].median())
print(df['Cholesterol'].std())
print(df['Cholesterol'].var())
# Out:
# 0
# 603
# 198.7995642701525
# 223.0
# 109.38414455220337
# 11964.891079417323

# %%
import matplotlib.pyplot as plt
plt.plot(df['Sex'],df['HeartDisease'])

# %%
max_cholesterol_age = df.loc[df['Cholesterol'].idxmax(), 'Age']
sex = df.loc[df['Cholesterol'].idxmax(),'Sex']
print(f"The age of the person with maximum cholesterol is: {max_cholesterol_age}, sex:{sex}")
# Out:
# The age of the person with maximum cholesterol is: 54, sex:M
